# %% [markdown]
# # 📘 Day 1 - Εισαγωγή στον Ρόλο του Data Engineer
#
# # ✍️ Ποιος είναι ο ρόλος του Data Engineer (με δικά μου λόγια):
# """
# Ο Data Engineer είναι υπεύθυνος για να μαζεύει, καθαρίζει και οργανώνει τα δεδομένα έτσι ώστε να είναι εύκολα αναλύσιμα και διαθέσιμα στους αναλυτές και επιστήμονες δεδομένων. Χτίζει pipelines, ελέγχει την ποιότητα των δεδομένων και φροντίζει να υπάρχουν στην κατάλληλη μορφή και αποθήκη.
# """
#
# # 🧠 Ποιες τεχνολογίες θα μάθω και γιατί:
# """
# Python → για επεξεργασία δεδομένων και scripting
# SQL → για ερωτήματα πάνω σε βάσεις δεδομένων
# Pandas → για ανάλυση και καθαρισμό δεδομένων
# Airflow → για αυτοματοποίηση ETL διαδικασιών
# dbt → για modular transformations
# Git → για version control στα projects
# Power BI → για dashboards και reports
# """
#
# # 🎯 Τι θέλω να πετύχω με αυτή την εκπαίδευση:
# """
# Να αποκτήσω πρακτική εμπειρία σε εργαλεία Data Engineering,
# να φτιάξω ποιοτικό portfolio με pipelines και dashboards
# και να είμαι έτοιμος για τη συνέντευξη Junior Data Engineer.
# """
