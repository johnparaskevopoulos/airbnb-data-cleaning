# %% [markdown]
# # 🐍 Day 2 – Python Basics: Μεταβλητές, Λίστες, Συναρτήσεις
#
# Σήμερα εξασκούμαι στα βασικά της Python για data επεξεργασία:
# - Δημιουργία μεταβλητών
# - Λίστες & λεξικά
# - Φόρτωση CSV
# - Καθαρισμός με Pandas

# %%
# 🔹 Μεταβλητές & Τύποι
name = "User"
year = 2025
data_ready = True
print(f"Γεια σου {name}, καλωσήρθες στο 2025!")

# 🔹 Λίστα & Λεξικό
devices = ["sensor1", "sensor2", "sensor3"]
info = {"project": "Energy", "sensors": 23}

print(devices[0])        # sensor1
print(info["project"])   # Energy

# 🔹 Συνάρτηση
def say_hello(name):
    return f"Hello, {name}!"

print(say_hello("Data Engineer"))
# Out:
# Γεια σου User, καλωσήρθες στο 2025!
# sensor1
# Energy
# Hello, Data Engineer!

# %%
# 📄 Διαβάζουμε CSV με Pandas
import pandas as pd

df = pd.read_csv("../data/test.csv")
print(df)

# Υπολογισμός μέσης τιμής
mean_val = df["value"].mean()
print("Μέση Τιμή:", mean_val)
# Out:
#   device_id  value
# 0      A123     10
# 1      B234     15
# 2      C345      8
# Μέση Τιμή: 11.0
